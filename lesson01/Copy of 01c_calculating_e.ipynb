# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/taobrienlbl/advanced_earth_science_data_analysis/blob/spring_2023_iub/lessons/01_fundamentals/01c_calculating_e.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# In this group exercise, you will mimic what we did with π: you will write code to calculate $e$ using the following series approximation (from [wikipedia](https://en.wikipedia.org/wiki/List_of_representations_of_e#As_an_infinite_series)):
#
#
# $$ e = \sum\limits_{k=0}^{\infty} \frac{1}{k!} $$
#
# where $k!$ represents 'k factorial': $k! = 1 \cdot 2 \cdot 3 \cdot \ldots \cdot k$

# %%
"""trying on my own"""
#initialize e (or k?)
e=0

# set number of iterations
K = 10000

# initialize empty list of k vals
k_values = []

# loop from 0 up to number of iterations
for k in range(0,K):
  # calculate the current term in the k approximation
  current_term = k

  #add to current value of k
  k = k * current_term +1

  #append k (what is this?)
  k_values.append(k)

#
print(k)
# Out:
# 99980002

# %%
from matplotlib._api.deprecation import math

# %%
"""with Elizabeth help"""
#initialize e (or k?)
e=0

# set number of iterations
K = 10000

# initialize empty list of e vals
e_values = []

# loop from 0 up to number of iterations
for k in range(0,K):
  # calculate the current term in the k approximation
  current_term = 1/math.factorial(k)

  #add to current value of k
  e = e + current_term

  #append k (what is this?)
  e_values.append(e)

#
print(e)
# Out:
# 2.7182818284590455

# %%
"""not using math factorial function"""
#initialize e (or k?)
e=0

# set number of iterations
K = 100

# initialize empty list of e vals
e_values = []

# loop from 0 up to number of iterations
for k in range(0,K):

#compute factorial. first define
  fact = 1

  for i in range(1,k+1):
    fact = i*fact


  # calculate the current term in the factorial approximation
  current_term = 1/fact

  #start adding the "e"s
  e = e + current_term

  #append e
  e_values.append(e)

#
print(e)
# Out:
# 2.7182818284590455
